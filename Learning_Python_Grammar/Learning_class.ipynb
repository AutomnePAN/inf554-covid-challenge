# %%
class Circle:
    
    def __init__(self, rayon = 0, x = 0, y = 0):
        self.r = rayon
        self.cx = x
        self.cy = y
    def print_circle(self):
        print("This circle's center is at  (" ,self.cx ,"," , self.cy , "), its rayon is: ",self.r)

# %%
C = Circle(10, 1,1)

# %%
C.print_circle()
# Out:
# This circle's center is at  ( 1 , 1 ), its rayon is:  10

# %%
class Student():
    
    def __init__(self, name, age, grade):
        self.name = name;
        self.age = age;
        self.grade = grade;
    def print_student(self):
        print("The student name is: ", self.name)

# %%
A = Student("Bob", 12, 98)

# %%
A.print_student()
# Out:
# The student name is:  Bob

# %%
class Highschool_Student(Student):
    def __init__(self, name, age, grade, level):
        super().__init__(name, age, grade);
        self.level = level;
    def print_student(self):
        super().print_student();
        print("The student is of ", self.level , " level")

# %%
B = Highschool_Student("Sam", 16, 87, 3)

# %%
B.print_student()
# Out:
# The student name is:  Sam
# The student is of  3  level

# %% [markdown]
# # A RPG Game Simulation

# %%
import random

# %%
class  Game_Object():
    def __init__(self, hp, hp_cel, att, defence, name, sex, knowledge):
        self.hp = hp;
        self.hp_cel = hp_cel;
        self.att = att;
        self.defen = defence;
        self.name = name;
        self.sex = sex;
        self.knowledge = knowledge;
    
    def attack(self, target):
        r = random.random();
        if r > target.defen/100:
            target.hp -= self.att;
            target.check_hp();
            print("+++++++++++++++++++++++++++++")
            print(self.name, " successfully attack ", target.name)
            print("+++++++++++++++++++++++++++++")
        else:
            print("+++++++++++++++++++++++++++++")
            print(self.name," failed to attack")
            print("+++++++++++++++++++++++++++++")
            
    def print_Character(self):
        print(self.name);
        print("hp: ", self.hp,"/", self.hp_cel)
        print("Attack: ", self.att)
        print("Defen: ", self.defen)
        if self.sex == 1:
            print("Sex: Male")
        elif self.sex == 0:
            print("Sex: Female")
        else:
            print("Sex: No sex")
        
    def check_hp(self):
        if(self.hp_cel / 2 < self.hp <= self.hp_cel):
            print(self.name," is wounded, his hp: ",self.hp);
        elif(0 < self.hp <= self.hp_cel/2):
            print(self.name," is heavily wounded, his hp: ",self.hp)
        else:
            self.hp = 0;
            print(self.name," is dead");       
        
    def healing(self):
        r = random.random()
        if r < self.knowledge / 100:
            print("*******************************")
            print ("You succeeded to heal!")
            self.hp += self.knowledge / 100 *(self.hp_cel - self.hp)
            print("*******************************")
        else:
            print("*******************************")
            print ("You failed to heal")
            print("*******************************")

# %%
class Goblin(Game_Object):
    def __init__(self):
        Game_Object.__init__(self, 100, 100, 50, 20, "Goblin", 2, 10);
        
    def attack(self, target):
        Game_Object.attack(self, target)
        if target.sex == 0:
            if random.random() > 0.5:
                print("Goblin got the girl!")
                target.hp_cel -= 10;

# %%
class Knight(Game_Object):
    def __init__(self):
        if random.random() > 0.5:
            Game_Object.__init__(self, 120, 120, 60, 60, "Knight", 0, 30)
        else:
            Game_Object.__init__(self, 120, 120, 60, 60, "Knight", 1, 30)
                
    def attack(self, target):
        Game_Object.attack(self, target)
        if target.defen < 50:
            target.hp -= 30
            target.check_hp();
            self.hp -= 5
            self.check_hp()
            print("Knight reduced the defence of the ", target.name)

# %%
class Witch(Game_Object):
    def __init__(self):
        Game_Object.__init__(self, 60, 60, 80, 30, "Witch", 0, 90)
        
        
    def attack(self, target):
        Game_Object.attack(self, target)
        if random.random() > 0.7:
            target.knowledge -= 10
        print("Witch enchant the ", target.name)

# %%
class Assassin(Game_Object):
    def __init__(self):
        if random.random() > 0.5:
            Game_Object.__init__(self, 80, 80, 30, 30, "Assassin", 0, 70)
        else:
            Game_Object.__init__(self, 80, 80, 30, 30, "Assassin", 1, 70)
    
    def attack(self, target):
        ask = random.random()
        if ask > 0.3:
            Game_Object.attack(self, target)
        else:
            print("+++++++++++++++++++++++++++++++++")
            print("The assassin attack silently! ")
            print("+++++++++++++++++++++++++++++++++")
            if random.random() > 0.5:
                target.hp -= 100;
                target.check_hp()

# %%
class Game():
    def __init__(self):
        p1 = random.randint(1,4)
        p2 = random.randint(1,4)
        if p1 == 1: 
            self.PC =  Goblin()
        elif p1 == 2:
            self.PC = Knight()
        elif p1 == 3:
            self.PC  = Witch()
        else:
            self.PC = Assassin()
        
        if p2 == 1: 
            self.Gamer =  Goblin()
        elif p2 == 2:
            self.Gamer = Knight()
        elif p2 == 3:
            self.Gamer  = Witch()
        else:
            self.Gamer = Assassin()
            
    def start(self):
        print("PC is: ", self.PC.name)
        self.PC.print_Character()
        print("Gamer is: ", self.Gamer.name)
        self.Gamer.print_Character()
        
    def Battle(self):
        if random.random() > 0.5:
            print("PC starts first! ")
            player = 0
        else:
            print("Gamer starts first! ")
            player = 1
        
        while (self.PC.hp > 0 and self.Gamer.hp > 0) :
            if player == 0:
                if self.PC.hp < self.PC.hp_cel:
                    if random.random() > 0.7:
                        self.PC.healing()
                    else:
                        self.PC.attack(self.Gamer);
                else:
                    self.PC.attack(self.Gamer)
                print("PC: ")
                self.PC.print_Character()
                print("--------------------")
                print("GAMER: ")
                self.Gamer.print_Character()
                print("\n ==== Round Over ====")
                player = 1 - player
                
            if player == 1:
                ans = input("You want to attack or healing ?")
                if (ans == "Attack"):
                    self.Gamer.attack(self.PC)
                else:
                    self.Gamer.healing()
                
                print("PC: ")
                self.PC.print_Character()
                print("--------------------")
                print("GAMER: ")
                self.Gamer.print_Character()
                print("\n ==== Round Over ====")
                player = 1 - player
                print("--------------------")
                self.Gamer.print_Character()
                print("\n ==== Round Over ====")
                player = 1 - player
        
        if (self.PC.hp  == 0):
            print("You have won the computer! ")
        else :
            print("You losed")

# %%
g = Game()
g.start()
g.Battle()
# Out:
# PC is:  Knight
# Knight
# hp:  120 / 120
# Attack:  60
# Defen:  60
# Sex: Female
# Gamer is:  Witch
# Witch
# hp:  60 / 60
# Attack:  80
# Defen:  30
# Sex: Female
# PC starts first!
# Witch  is dead
# +++++++++++++++++++++++++++++
# Knight  successfully attack  Witch
# +++++++++++++++++++++++++++++
# Witch  is dead
# Knight  is wounded, his hp:  115
# Knight reduced the defence of the  Witch
# PC:
# Knight
# hp:  115 / 120
# Attack:  60
# Defen:  60
# Sex: Female
# --------------------
# GAMER:
# Witch
# hp:  0 / 60
# Attack:  80
# Defen:  30
# Sex: Female
#
#  ==== Round Over ====
# You want to attack or healing ?healing
# *******************************
# You succeeded to heal!
# *******************************
# PC:
# Knight
# hp:  115 / 120
# Attack:  60
# Defen:  60
# Sex: Female
# --------------------
# GAMER:
# Witch
# hp:  54.0 / 60
# Attack:  80
# Defen:  30
# Sex: Female
#
#  ==== Round Over ====
# --------------------
# Witch
# hp:  54.0 / 60
# Attack:  80
# Defen:  30
# ...

# %%
ans = input("hidhuhsidw")
print(type(ans))
print(ans == 1)
# Out:
# hidhuhsidw1
# <class 'str'>
# False
