# %%
class Solution:
    """
    @param candidates: A list of integers
    @param target: An integer
    @return: A list of lists of integers
    """
    def combinationSum(self, candidates, target):
        # write your code here
        candidates = sorted(list(set(candidates)));
        results = []
        self.dfs(candidates, target, 0, results, []);
        return results
        
    
    def dfs(self, candidates, target, start, results, combination):
        if target == 0:
            results.append(list(combination)) 
            
        for i in range(start, len(candidates)):
            if target < candidates[i]:
                return;
            
            combination.append(candidates[i]);
            self.dfs(candidates, target - candidates[i], i, results, combination);
            combination.pop();

# %%
s = Solution()

# %%
s.combinationSum([2,3,6,7], 7)
# Out:
# [[2, 2, 3], [7]]

# %%
class Solution:
    """
    @param: s: A string
    @return: A list of lists of string
    """
    def partition(self, s):
        # write your code here
        
        n = len(s)
        
        res = [];
        is_Palindrome = True;
        for i in range( n//2 + 1 ):
            if s[i] != s[len(s)-1-i]:
                is_Palindrome = False;
        
        if is_Palindrome:
            res.append([s])
            
        for i in range(1, n):
            left_partition = self.partition(s[:i])
            right_partition = self.partition(s[i:])
            # print(left_partition);
            # print(right_partition)
            for left_part in left_partition:
                for right_part in right_partition:
                    pre_res = left_part + right_part;
                    if not pre_res in res:
                        res.append(left_part + right_part);
        
        return res;

# %%
s = Solution()

# %%
s.partition("abccdchbwsjwoidwoixgwguuqoioqwiwwdd")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-90004a923443> in <module>
# ----> 1 s.partition("abccdchbwsjwoidwoixgwguuqoioqwiwwdd")
#
# <ipython-input-4-b948df42ad6e> in partition(self, s)
#      20         for i in range(1, n):
#      21             left_partition = self.partition(s[:i])
# ---> 22             right_partition = self.partition(s[i:])
#      23             # print(left_partition);
#      24             # print(right_partition)
#
# <ipython-input-4-b948df42ad6e> in partition(self, s)
#      20         for i in range(1, n):
#      21             left_partition = self.partition(s[:i])
# ---> 22             right_partition = self.partition(s[i:])
#      23             # print(left_partition);
#      24             # print(right_partition)
#
# <ipython-input-4-b948df42ad6e> in partition(self, s)
#      20         for i in range(1, n):
# ...
